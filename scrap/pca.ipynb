# %% [markdown]
# # PCA visualization

# %%
# --- Spotify PCA + KMeans Notebook ---

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Plot style
sns.set(style="whitegrid", context="talk")
plt.rcParams["figure.figsize"] = (10, 7)
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # --- Spotify PCA + KMeans Notebook ---
# ----> 3 import pandas as pd
#       4 import numpy as np
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Load

# %%
# Path to your CSV
data_path = "spotify_tracks.csv"  # TODO: change this

df = pd.read_csv(data_path)

print("Shape:", df.shape)
df.head()

# %% [markdown]
# # Select features & cleaning

# %%
# Columns in your example:
# id,name,duration,energy,key,loudness,mode,speechiness,acousticness,
# instrumentalness,liveness,valence,tempo,danceability

id_col = "id"
name_col = "name"

feature_cols = [
    "duration",
    "energy",
    "key",
    "loudness",
    "mode",
    "speechiness",
    "acousticness",
    "instrumentalness",
    "liveness",
    "valence",
    "tempo",
    "danceability",
]

# Keep only rows with no missing values in features
df_features = df[feature_cols].dropna()

print("Original rows:", df.shape[0])
print("Rows after dropping NA:", df_features.shape[0])

df_features.describe().T
